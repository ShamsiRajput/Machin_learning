# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
print ("all library is included")
# Out:
# all library is included

# %%
warnings.filterwarnings('ignore')
df=pd.read_csv('insurance (1).csv')
df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
df.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='object')

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
df.shape
# Out:
# (1338, 7)

# %%
df.duplicated().sum()
# Out:
# np.int64(1)

# %%
df.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='object')

# %%
numarical_values=['age','bmi','children','charges']
numarical_values
# Out:
# ['age', 'bmi', 'children', 'charges']

# %%
for col in numarical_values:
    plt.figure(figsize=(6,4))
    sns.histplot(df[col],bins=10,kde=True)

# %%
plt.figure(figsize=(6,4))
sns.countplot(x=df['sex'])
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
plt.figure(figsize=(6,4))
sns.countplot(x=df['smoker'])
# Out:
# <Axes: xlabel='smoker', ylabel='count'>

# %%
plt.figure(figsize=(8,6))
sns.countplot(x=df['region'])
# Out:
# <Axes: xlabel='region', ylabel='count'>

# %%
for col in numarical_values:
    plt.figure(figsize=(8,6))
    sns.boxplot(x=df[col])

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df.corr(numeric_only=True),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# #data cleaning

# %%
copy_data=df.copy()

# %%
copy_data.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
copy_data.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='object')

# %%
print(copy_data.duplicated().sum())
# Out:
# 1

# %%
copy_data.drop_duplicates(inplace=True)

# %%
copy_data.shape
# Out:
# (1337, 7)

# %%
copy_data.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
copy_data.dtypes
# Out:
# age           int64
# sex          object
# bmi         float64
# children      int64
# smoker       object
# region       object
# charges     float64
# dtype: object

# %%
np.mean(copy_data['age'])
# Out:
# np.float64(39.222139117427076)

# %%
    for col in numarical_values:
        np.mean(copy_data[col])

# %%
copy_data['sex'].value_counts()
# Out:
# sex
# male      675
# female    662
# Name: count, dtype: int64

# %%
copy_data['smoker'].value_counts()
# Out:
# smoker
# no     1063
# yes     274
# Name: count, dtype: int64

# %%
copy_data['region'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0       southwest
# 1       southeast
# 2       southeast
# 3       northwest
# 4       northwest
#           ...
# 1333    northwest
# 1334    northeast
# 1335    southeast
# 1336    southwest
# 1337    northwest
# Name: region, Length: 1337, dtype: object>

# %%
copy_data['sex']=copy_data['sex'].map({"male" : 0 ,"female" : 1})

# %%
copy_data.head()
# Out:
#    age  sex     bmi  children smoker     region      charges
# 0   19    1  27.900         0    yes  southwest  16884.92400
# 1   18    0  33.770         1     no  southeast   1725.55230
# 2   28    0  33.000         3     no  southeast   4449.46200
# 3   33    0  22.705         0     no  northwest  21984.47061
# 4   32    0  28.880         0     no  northwest   3866.85520

# %%
copy_data['smoker'].value_counts()
# Out:
# smoker
# no     1063
# yes     274
# Name: count, dtype: int64

# %%
copy_data['smoker']=copy_data['smoker'].map({'no':0,'yes':1})

# %%
copy_data.head()
# Out:
#    age  sex     bmi  children  smoker     region      charges
# 0   19    1  27.900         0       1  southwest  16884.92400
# 1   18    0  33.770         1       0  southeast   1725.55230
# 2   28    0  33.000         3       0  southeast   4449.46200
# 3   33    0  22.705         0       0  northwest  21984.47061
# 4   32    0  28.880         0       0  northwest   3866.85520

# %%
copy_data.rename(columns={
'sex':'isFemale','smoker':'isSmoker'}

    
,inplace=True)

# %%
copy_data
# Out:
#       age  isFemale     bmi  children  isSmoker     region      charges
# 0      19         1  27.900         0         1  southwest  16884.92400
# 1      18         0  33.770         1         0  southeast   1725.55230
# 2      28         0  33.000         3         0  southeast   4449.46200
# 3      33         0  22.705         0         0  northwest  21984.47061
# 4      32         0  28.880         0         0  northwest   3866.85520
# ...   ...       ...     ...       ...       ...        ...          ...
# 1333   50         0  30.970         3         0  northwest  10600.54830
# 1334   18         1  31.920         0         0  northeast   2205.98080
# 1335   18         1  36.850         0         0  southeast   1629.83350
# 1336   21         1  25.800         0         0  southwest   2007.94500
# 1337   61         1  29.070         0         1  northwest  29141.36030
#
# [1337 rows x 7 columns]

# %%
copy_data.columns
# Out:
# Index(['age', 'isFemale', 'bmi', 'children', 'isSmoker', 'region', 'charges'], dtype='object')

# %%
copy_data['region'].value_counts()
# Out:
# region
# southeast    364
# southwest    325
# northwest    324
# northeast    324
# Name: count, dtype: int64

# %%
copy_data=pd.get_dummies(copy_data,columns=['region'])

# %%
copy_data
# Out:
#       age  isFemale     bmi  children  isSmoker      charges  \
# 0      19         1  27.900         0         1  16884.92400
# 1      18         0  33.770         1         0   1725.55230
# 2      28         0  33.000         3         0   4449.46200
# 3      33         0  22.705         0         0  21984.47061
# 4      32         0  28.880         0         0   3866.85520
# ...   ...       ...     ...       ...       ...          ...
# 1333   50         0  30.970         3         0  10600.54830
# 1334   18         1  31.920         0         0   2205.98080
# 1335   18         1  36.850         0         0   1629.83350
# 1336   21         1  25.800         0         0   2007.94500
# 1337   61         1  29.070         0         1  29141.36030
#
#       region_northeast  region_northwest  region_southeast  region_southwest
# 0                False             False             False              True
# 1                False             False              True             False
# ...

# %%
copy_data=copy_data.astype(int)

# %%
copy_data
# Out:
#       age  isFemale  bmi  children  isSmoker  charges  region_northeast  \
# 0      19         1   27         0         1    16884                 0
# 1      18         0   33         1         0     1725                 0
# 2      28         0   33         3         0     4449                 0
# 3      33         0   22         0         0    21984                 0
# 4      32         0   28         0         0     3866                 0
# ...   ...       ...  ...       ...       ...      ...               ...
# 1333   50         0   30         3         0    10600                 0
# 1334   18         1   31         0         0     2205                 1
# 1335   18         1   36         0         0     1629                 0
# 1336   21         1   25         0         0     2007                 0
# 1337   61         1   29         0         1    29141                 0
#
#       region_northwest  region_southeast  region_southwest
# ...
